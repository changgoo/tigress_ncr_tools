# %%
from pathena.slicevtk_reader import read_slicevtk, read_all_slicevtks, print_metadata, plot_plane

# %%
basedir = "/scratch/gpfs/changgoo/TIGRESS-NCR-debug/R8_8pc_NCR"
problem_id = "R8_8pc_NCR"

# %%
slc_dict = read_all_slicevtks(basedir, problem_id)

# %%
print_metadata(slc_dict["midplane"][0])

# %%
fig, axes = plot_plane(slc_dict["midplane"][10],plane="x3")
